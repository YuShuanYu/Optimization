# %%
import copy

# %%
xcoord = [  35.00      , 41.00      , 35.00      , 55.00      , 55.00      , 15.00      , 25.00      , 20.00      , 10.00      , 55.00      , 30.00      , 20.00      , 50.00      , 30.00      , 15.00      , 30.00      , 10.00      ,   5.00      , 20.00      , 15.00      , 45.00      , 45.00      , 45.00      , 55.00      , 65.00      , 65.00      , 45.00      , 35.00      , 41.00      , 64.00      , 40.00      , 31.00      , 35.00      , 53.00      , 65.00      , 63.00      ,   2.00      , 20.00      ,   5.00      , 60.00      , 40.00      , 42.00      , 24.00      , 23.00      , 11.00      ,   6.00      ,   2.00      ,   8.00      , 13.00      ,   6.00      , 47.00      , 49.00      , 27.00      , 37.00      , 57.00      , 63.00      , 53.00      , 32.00      , 36.00      , 21.00      , 17.00      , 12.00      , 24.00      , 27.00      , 15.00      , 62.00      , 49.00      , 67.00      , 56.00      , 37.00      , 37.00      , 57.00      , 47.00      , 44.00      , 46.00      , 49.00      , 49.00      , 53.00      , 61.00      , 57.00      , 56.00      , 55.00      , 15.00      , 14.00      , 11.00      , 16.00      ,   4.00      , 28.00      , 26.00      , 26.00      , 31.00      , 15.00      , 22.00      , 18.00      , 26.00      , 25.00      , 22.00      , 25.00      , 19.00      , 20.00      , 18.00   ]  
ycoord =[ 35.00    , 49.00    , 17.00    , 45.00    , 20.00    , 30.00    , 30.00    , 50.00    , 43.00    , 60.00    , 60.00    , 65.00    , 35.00    , 25.00    , 10.00    ,   5.00    , 20.00    , 30.00    , 40.00    , 60.00    , 65.00    , 20.00    , 10.00    ,   5.00    , 35.00    , 20.00    , 30.00    , 40.00    , 37.00    , 42.00    , 60.00    , 52.00    , 69.00    , 52.00    , 55.00    , 65.00    , 60.00    , 20.00    ,   5.00    , 12.00    , 25.00    ,   7.00    , 12.00    ,   3.00    , 14.00    , 38.00    , 48.00    , 56.00    , 52.00    , 68.00    , 47.00    , 58.00    , 43.00    , 31.00    , 29.00    , 23.00    , 12.00    , 12.00    , 26.00    , 24.00    , 34.00    , 24.00    , 58.00    , 69.00    , 77.00    , 77.00    , 73.00    ,   5.00    , 39.00    , 47.00    , 56.00    , 68.00    , 16.00    , 17.00    , 13.00    , 11.00    , 42.00    , 43.00    , 52.00    , 48.00    , 37.00    , 54.00    , 47.00    , 37.00    , 31.00    , 22.00    , 18.00    , 18.00    , 52.00    , 35.00    , 67.00    , 19.00    , 22.00    , 24.00    , 27.00    , 24.00    , 27.00    , 21.00    , 21.00    , 26.00    , 18.00   ]
demand   =[    0.00    ,    10.00    ,     7.00    ,    13.00    ,    19.00    ,    26.00    ,     3.00    ,     5.00    ,     9.00    ,    16.00    ,    16.00    ,    12.00    ,    19.00    ,    23.00    ,    20.00    ,     8.00    ,    19.00    ,     2.00    ,    12.00    ,    17.00    ,     9.00    ,    11.00    ,    18.00    ,    29.00    ,     3.00    ,     6.00    ,    17.00    ,    16.00    ,    16.00    ,     9.00    ,    21.00    ,    27.00    ,    23.00    ,    11.00    ,    14.00    ,     8.00    ,     5.00    ,     8.00    ,    16.00    ,    31.00    ,     9.00    ,     5.00    ,     5.00    ,     7.00    ,    18.00    ,    16.00    ,     1.00    ,    27.00    ,    36.00    ,    30.00    ,    13.00    ,    10.00    ,     9.00    ,    14.00    ,    18.00    ,     2.00    ,     6.00    ,     7.00    ,    18.00    ,    28.00    ,     3.00    ,    13.00    ,    19.00    ,    10.00    ,     9.00    ,    20.00    ,    25.00    ,    25.00    ,    36.00    ,     6.00    ,     5.00    ,    15.00    ,    25.00    ,     9.00    ,     8.00    ,    18.00    ,    13.00    ,    14.00    ,     3.00    ,    23.00    ,     6.00    ,    26.00    ,    16.00    ,    11.00    ,     7.00    ,    41.00    ,    35.00    ,    26.00    ,     9.00    ,    15.00    ,     3.00    ,     1.00    ,     2.00    ,    22.00    ,    27.00    ,    20.00    ,    11.00    ,    12.00    ,    10.00    ,     9.00    ,    17.00  ] 
ready_time =[     0.00     ,   161.00     ,    50.00     ,   116.00     ,   149.00     ,    34.00     ,    99.00     ,    81.00     ,    95.00     ,    97.00     ,   124.00     ,    67.00     ,    63.00     ,   159.00     ,    32.00     ,    61.00     ,    75.00     ,   157.00     ,    87.00     ,    76.00     ,   126.00     ,    62.00     ,    97.00     ,    68.00     ,   153.00     ,   172.00     ,   132.00     ,    37.00     ,    39.00     ,    63.00     ,    71.00     ,    50.00     ,   141.00     ,    37.00     ,   117.00     ,   143.00     ,    41.00     ,   134.00     ,    83.00     ,    44.00     ,    85.00     ,    97.00     ,    31.00     ,   132.00     ,    69.00     ,    32.00     ,   117.00     ,    51.00     ,   165.00     ,   108.00     ,   124.00     ,    88.00     ,    52.00     ,    95.00     ,   140.00     ,   136.00     ,   130.00     ,   101.00     ,   200.00     ,    18.00     ,   162.00     ,    76.00     ,    58.00     ,    34.00     ,    73.00     ,    51.00     ,   127.00     ,    83.00     ,   142.00     ,    50.00     ,   182.00     ,    77.00     ,    35.00     ,    78.00     ,   149.00     ,    69.00     ,    73.00     ,   179.00     ,    96.00     ,    92.00     ,   182.00     ,    94.00     ,    55.00     ,    44.00     ,   101.00     ,    91.00     ,    94.00     ,    93.00     ,    74.00     ,   176.00     ,    95.00     ,   160.00     ,    18.00     ,   188.00     ,   100.00     ,    39.00     ,   135.00     ,   133.00     ,    58.00     ,    83.00     ,   185.00   ] 
due_time =[  230.00      , 171.00      ,   60.00      , 126.00      , 159.00      ,   44.00      , 109.00      ,   91.00      , 105.00      , 107.00      , 134.00      ,   77.00      ,   73.00      , 169.00      ,   42.00      ,   71.00      ,   85.00      , 167.00      ,   97.00      ,   86.00      , 136.00      ,   72.00      , 107.00      ,   78.00      , 163.00      , 182.00      , 142.00      ,   47.00      ,   49.00      ,   73.00      ,   81.00      ,   60.00      , 151.00      ,   47.00      , 127.00      , 153.00      ,   51.00      , 144.00      ,   93.00      ,   54.00      ,   95.00      , 107.00      ,   41.00      , 142.00      ,   79.00      ,   42.00      , 127.00      ,   61.00      , 175.00      , 118.00      , 134.00      ,   98.00      ,   62.00      , 105.00      , 150.00      , 146.00      , 140.00      , 111.00      , 210.00      ,   28.00      , 172.00      ,   86.00      ,   68.00      ,   44.00      ,   83.00      ,   61.00      , 137.00      ,   93.00      , 152.00      ,   60.00      , 192.00      ,   87.00      ,   45.00      ,   88.00      , 159.00      ,   79.00      ,   83.00      , 189.00      , 106.00      , 102.00      , 192.00      , 104.00      ,   65.00      ,   54.00      , 111.00      , 101.00      , 104.00      , 103.00      ,   84.00      , 186.00      , 105.00      , 170.00      ,   28.00      , 198.00      , 110.00      ,   49.00      , 145.00      , 143.00      ,   68.00      ,   93.00      , 195.00     ]
service_time =[  0.00 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10 , 10]
capacity = 200
M = 100000
acw = -10

# %%
n = len(xcoord)
link = []
for i in range(1,n):
    link.append([0,i])
    link.append([i,0])

# %%
distance_matrix = []
for i in range(n):
    distance_list = []
    for j in range(n):
        if i == j:
            distance_list.append(M)
        else:
            distance_list.append(((xcoord[i]-xcoord[j])**2+(ycoord[i]-ycoord[j])**2)**0.5)
    distance_matrix.append(distance_list)

# %%
total_distance = 0
for i in link:
    total_distance += distance_matrix[i[0]][i[1]]

# %%
#排序過的route
#route = []
#sortindex = sorted(range(len(ready_time)), key=lambda k: ready_time[k])
#for i in sortindex:
#    route.append([i])
#del route[0]

# %%
#為排序過的route
route = []
for i in range(1,n):
    route.append([i])
print "Number of cars is",len(route)
# Out:
# Number of cars is 100

# %%
#計算每一點最初的離開時間
leavetime = []
for i in route:
    counttime = distance_matrix[0][i[0]]
    if counttime < ready_time[i[0]]:
        counttime = ready_time[i[0]]+service_time[i[0]]    
    else:
        counttime += service_time[i[0]]
    leavetime.append([counttime])

# %%
update_route = 1
count = 1
while update_route == 1:
    print '----------第幾次：',count,'--------'
    update_route = 0
    for indexi,i in enumerate(route):
        print '----結合1',i
        istart = i[0]
        iend = i[-1]
        sav = []
        for indexj,j in enumerate(route):
            if i != j:
                print '結合2',j
                jstart = j[0]
                jend = j[-1]
                savingtime = distance_matrix[iend][0]+distance_matrix[0][jstart]-distance_matrix[iend][jstart]
                sav.append([savingtime,[indexi,indexj],1])
                if len(j) >= 2:
                    savingtime = distance_matrix[iend][0]+distance_matrix[jend][0]-distance_matrix[iend][jend]
                    sav.append([savingtime,[indexi,indexj],-1])   
            
        sav.sort(reverse = True)
        for s in sav:
            route_change = copy.deepcopy(route[s[1][0]])
            indexrc = len(route_change)
            if s[2] == 1:
                rex = route[s[1][1]]
            else:
                rex = list(reversed(route[s[1][1]]))
            
            route_change.extend(rex)
            totaldemand = 0
            for r in route_change:
                totaldemand += demand[r]
            if totaldemand < 200:
                leavetimechange = copy.deepcopy(leavetime[s[1][0]])
                for indexr,r in enumerate(route_change):
                    if indexr < indexrc:
                        continue
                    else:
                        if leavetimechange[-1]+distance_matrix[route_change[indexr-1]][r]+service_time[r] >= due_time[r]:
                            print rex,'over due time'
                            break
                        else:
                            waitt = leavetimechange[-1]+distance_matrix[route_change[indexr-1]][r] - ready_time[r]
                            if (waitt < 0) & (waitt > acw):
                                leavetimechange.append(ready_time[r]+service_time[r])
                            elif waitt >= 0:
                                leavetimechange.append(leavetimechange[-1]+distance_matrix[route_change[indexr-1]][r]+service_time[r])
                            else:
                                print rex,'over waiting limit'
                                break
                        if r == route_change[-1]:
                            if leavetimechange[-1]+distance_matrix[r][0] <= due_time[0]:
                                update_route = 1
                                print rex,'update!'
                                leavetime[s[1][0]]=leavetimechange
                                route[s[1][0]] = route_change
                                del leavetime[s[1][1]]
                                del route[s[1][1]]
                                break
            else:
                print s,'over capacity'
                continue
            if update_route == 1:
                break
        if update_route == 1:
            count += 1
            break
# Out:
# ----------第幾次： 1 --------
# ----結合1 [1]
# 結合2 [2]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [22]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [70]
# 結合2 [71]
# 結合2 [72]
# 結合2 [73]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [66] over due time
# [20] over due time
# [65] over due time
# [51] over due time
# [71] over due time
# [30] over due time
# [9] over due time
# [35] over due time
# [32] over due time
# [70] update!
# ----------第幾次： 2 --------
# ----結合1 [1, 70]
# 結合2 [2]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [22]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [73]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [91] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [73] over due time
# [22] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [43] over due time
# [87] over due time
# [58] over due time
# [2] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [22]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [73]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [15] over due time
# [57] over waiting limit
# [41] over waiting limit
# [43] over waiting limit
# [22] over waiting limit
# [42] over due time
# [74] over waiting limit
# [23] over due time
# [75] over due time
# [87] over waiting limit
# [73] update!
# ----------第幾次： 3 --------
# ----結合1 [1, 70]
# 結合2 [2, 73]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [22]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [91] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [73, 2] over due time
# [22] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [43] over due time
# [87] over due time
# [58] over due time
# [2, 73] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [22]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [74] over waiting limit
# [75] over due time
# [22] update!
# ----------第幾次： 4 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [91] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [22, 73, 2] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [43] over due time
# [87] over due time
# [58] over due time
# [2, 73, 22] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [43]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [23] over due time
# [41] over due time
# [75] over due time
# [74] over waiting limit
# [67] over due time
# [56] over waiting limit
# [39] over due time
# [72] over due time
# [15] over due time
# [25] over waiting limit
# [43] update!
# ----------第幾次： 5 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22, 43]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [91] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [43, 22, 73, 2] over due time
# [87] over due time
# [58] over due time
# [2, 73, 22, 43] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22, 43]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [91]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [38] over due time
# [15] over due time
# [14] over due time
# [42] over due time
# [44] over due time
# [86] over due time
# [57] over due time
# [41] over due time
# [100] over waiting limit
# [16] over due time
# [91] update!
# ----------第幾次： 6 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22, 43, 91]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [91, 43, 22, 73, 2] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [87] over due time
# [58] over due time
# [2, 73, 22, 43, 91] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22, 43, 91]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [58]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [44] over due time
# [38] over due time
# [86] over due time
# [16] over due time
# [14] over due time
# [100] over waiting limit
# [85] over due time
# [61] over due time
# [98] over due time
# [37] over due time
# [17] over due time
# [93] over waiting limit
# [42] over due time
# [84] over due time
# [92] over due time
# [59] over due time
# [15] over due time
# [5] over due time
# [99] over due time
# [45] over due time
# [97] over due time
# [87] over due time
# [57] over due time
# [96] over due time
# [46] over due time
# [95] over due time
# [83] over due time
# [60] over due time
# [8] over due time
# [41] over due time
# [94] over due time
# [36] over due time
# [47] over due time
# [6] over due time
# [82] over due time
# [13] over due time
# [48] over due time
# [18] over due time
# [49] over due time
# [23] over due time
# [74] over due time
# [75] over due time
# [19] over due time
# [56] over due time
# [72] over due time
# [67] over due time
# [7] over due time
# [89] over due time
# [64] over due time
# [39] over due time
# [21] over due time
# [11] over due time
# [58] update!
# ----------第幾次： 7 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [87] over due time
# [58, 91, 43, 22, 73, 2] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22, 43, 91, 58]
# 結合2 [1, 70]
# 結合2 [3]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [41] over due time
# [57] over due time
# [15] over due time
# [74] over due time
# [75] over due time
# [23] over due time
# [72] over due time
# [21] over due time
# [56] over due time
# [87] over due time
# [40] over due time
# [42] over due time
# [67] over due time
# [39] over due time
# [14] over due time
# [97] over due time
# [13] over due time
# [4] over due time
# [38] over due time
# [100] over due time
# [44] over due time
# [37] over due time
# [25] over due time
# [92] over due time
# [95] over due time
# [98] over due time
# [55] over due time
# [59] over due time
# [85] over due time
# [16] over due time
# [86] over due time
# [93] over due time
# [94] over due time
# [54] over due time
# [99] over due time
# [61] over due time
# [26] over due time
# [96] over due time
# [24] over due time
# [6] over due time
# [53] over due time
# [5] over due time
# [17] over due time
# [84] over due time
# [12] over due time
# [80] over due time
# [29] over due time
# [68] over due time
# [60] over due time
# [45] over due time
# [83] over due time
# [77] over due time
# [89] over due time
# [3] over due time
# [8] over due time
# [79] over due time
# [34] over due time
# [76] over due time
# [78] over due time
# [46] over due time
# [18] over due time
# [28] over due time
# [81] over due time
# [33] over due time
# [82] over due time
# [35] over due time
# [36] over due time
# [50] over due time
# [47] over due time
# [48] over due time
# [9] over due time
# [71] over due time
# [65] over due time
# [51] over due time
# [7] over due time
# [49] over due time
# [52] over due time
# [19] over due time
# [66] over due time
# [1, 70] over due time
# [20] over due time
# [11] over due time
# [88] over due time
# [64] over due time
# [62] over due time
# [30] over due time
# [69] over due time
# [70, 1] over due time
# [63] over due time
# [32] over due time
# [31] over due time
# [10] over due time
# [27] over due time
# [90] over due time
# ----結合1 [3]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [68]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [79] over due time
# [34] over due time
# [78] over due time
# [29] over due time
# [35] over due time
# [81] over due time
# [33] over due time
# [65] over due time
# [9] over due time
# [77] over waiting limit
# [71] over due time
# [24] over waiting limit
# [68] update!
# ----------第幾次： 8 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3, 68]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3, 68] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68, 3] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [87] over due time
# [58, 91, 43, 22, 73, 2] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22, 43, 91, 58]
# 結合2 [1, 70]
# 結合2 [3, 68]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [41] over due time
# [57] over due time
# [15] over due time
# [74] over due time
# [75] over due time
# [23] over due time
# [72] over due time
# [21] over due time
# [56] over due time
# [87] over due time
# [40] over due time
# [42] over due time
# [67] over due time
# [39] over due time
# [14] over due time
# [97] over due time
# [13] over due time
# [4] over due time
# [38] over due time
# [100] over due time
# [44] over due time
# [37] over due time
# [25] over due time
# [92] over due time
# [95] over due time
# [98] over due time
# [55] over due time
# [59] over due time
# [85] over due time
# [16] over due time
# [86] over due time
# [93] over due time
# [94] over due time
# [54] over due time
# [99] over due time
# [61] over due time
# [26] over due time
# [96] over due time
# [24] over due time
# [6] over due time
# [53] over due time
# [5] over due time
# [17] over due time
# [84] over due time
# [12] over due time
# [80] over due time
# [29] over due time
# [68, 3] over due time
# [60] over due time
# [45] over due time
# [83] over due time
# [77] over due time
# [89] over due time
# [3, 68] over due time
# [8] over due time
# [79] over due time
# [34] over due time
# [76] over due time
# [78] over due time
# [46] over due time
# [18] over due time
# [28] over due time
# [81] over due time
# [33] over due time
# [82] over due time
# [35] over due time
# [36] over due time
# [50] over due time
# [47] over due time
# [48] over due time
# [9] over due time
# [71] over due time
# [65] over due time
# [51] over due time
# [7] over due time
# [49] over due time
# [52] over due time
# [19] over due time
# [66] over due time
# [1, 70] over due time
# [20] over due time
# [11] over due time
# [88] over due time
# [64] over due time
# [62] over due time
# [30] over due time
# [69] over due time
# [70, 1] over due time
# [63] over due time
# [32] over due time
# [31] over due time
# [10] over due time
# [27] over due time
# [90] over due time
# ----結合1 [3, 68]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [4]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [29] over due time
# [24] over due time
# [80] over waiting limit
# [34] over due time
# [78] over due time
# [79] over due time
# [77] over waiting limit
# [35] over due time
# [55] over due time
# [54] over due time
# [81] over due time
# [25] over due time
# [65] over due time
# [33] over due time
# [9] over due time
# [71] over due time
# [67] over due time
# [76] over due time
# [12] over due time
# [51] over due time
# [39] over due time
# [4] over due time
# [66] over due time
# [50] over due time
# [20] over due time
# [23] over due time
# [56] over due time
# [30] over due time
# [75] over due time
# [72] over due time
# [32] over due time
# [1, 70] over due time
# [26] over due time
# [74] over due time
# [21] over due time
# [70, 1] over due time
# [90] over due time
# [41] over due time
# [63] over due time
# [10] over due time
# [69] over due time
# [28] over due time
# [64] over due time
# [40] over due time
# [31] over due time
# [11] over due time
# [62] over due time
# [15] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [57] over due time
# [88] over due time
# [49] over due time
# [19] over due time
# [58, 91, 43, 22, 73, 2] over waiting limit
# [27] over due time
# [53] over due time
# [42] over due time
# [7] over due time
# [36] over due time
# [87] over due time
# [47] over due time
# [48] over due time
# [52] over due time
# [14] over due time
# [13] over due time
# [82] over due time
# [97] over due time
# [38] over due time
# [46] over due time
# [100] over due time
# [37] over due time
# [95] over due time
# [44] over due time
# [92] over due time
# [98] over due time
# [8] over due time
# [18] over due time
# [94] over due time
# [59] over due time
# [85] over due time
# [93] over due time
# [16] over due time
# [86] over due time
# [99] over due time
# [96] over due time
# [45] over due time
# [83] over due time
# [61] over due time
# [6] over due time
# [89] over due time
# [60] over due time
# [5] over due time
# [17] over due time
# [84] over due time
# ----結合1 [4]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3, 68]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [25]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [67] over due time
# [39] over due time
# [25] update!
# ----------第幾次： 9 --------
# ----結合1 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3, 68]
# 結合2 [4, 25]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [32] over due time
# [30] over due time
# [90] over due time
# [66] over due time
# [20] over due time
# [63] over due time
# [10] over due time
# [65] over due time
# [71] over due time
# [64] over due time
# [51] over due time
# [11] over due time
# [9] over due time
# [35] over due time
# [62] over due time
# [49] over due time
# [31] over due time
# [19] over due time
# [81] over due time
# [33] over due time
# [34] over due time
# [88] over due time
# [78] over due time
# [36] over due time
# [47] over due time
# [79] over due time
# [50] over due time
# [48] over due time
# [7] over due time
# [69] over due time
# [3, 68] over due time
# [46] over due time
# [82] over due time
# [29] over due time
# [77] over due time
# [76] over due time
# [8] over due time
# [68, 3] over due time
# [24] over due time
# [52] over due time
# [80] over due time
# [45] over due time
# [18] over due time
# [83] over due time
# [12] over due time
# [54] over due time
# [17] over due time
# [27] over due time
# [55] over due time
# [60] over due time
# [84] over due time
# [25, 4] over due time
# [28] over due time
# [5] over due time
# [89] over due time
# [86] over due time
# [61] over due time
# [4, 25] over due time
# [67] over due time
# [39] over due time
# [16] over due time
# [26] over due time
# [85] over due time
# [93] over due time
# [99] over due time
# [96] over due time
# [6] over due time
# [44] over due time
# [56] over due time
# [38] over due time
# [59] over due time
# [23] over due time
# [98] over due time
# [100] over due time
# [37] over due time
# [72] over due time
# [92] over due time
# [75] over due time
# [21] over due time
# [94] over due time
# [14] over due time
# [95] over due time
# [74] over due time
# [97] over due time
# [40] over due time
# [42] over due time
# [41] over due time
# [53] over due time
# [13] over due time
# [87] over due time
# [58, 91, 43, 22, 73, 2] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [15] over due time
# [57] over due time
# ----結合1 [2, 73, 22, 43, 91, 58]
# 結合2 [1, 70]
# 結合2 [3, 68]
# 結合2 [4, 25]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [41] over due time
# [57] over due time
# [15] over due time
# [74] over due time
# [75] over due time
# [23] over due time
# [72] over due time
# [21] over due time
# [56] over due time
# [87] over due time
# [40] over due time
# [42] over due time
# [67] over due time
# [39] over due time
# [14] over due time
# [97] over due time
# [13] over due time
# [4, 25] over due time
# [38] over due time
# [100] over due time
# [44] over due time
# [37] over due time
# [25, 4] over due time
# [92] over due time
# [95] over due time
# [98] over due time
# [55] over due time
# [59] over due time
# [85] over due time
# [16] over due time
# [86] over due time
# [93] over due time
# [94] over due time
# [54] over due time
# [99] over due time
# [61] over due time
# [26] over due time
# [96] over due time
# [24] over due time
# [6] over due time
# [53] over due time
# [5] over due time
# [17] over due time
# [84] over due time
# [12] over due time
# [80] over due time
# [29] over due time
# [68, 3] over due time
# [60] over due time
# [45] over due time
# [83] over due time
# [77] over due time
# [89] over due time
# [3, 68] over due time
# [8] over due time
# [79] over due time
# [34] over due time
# [76] over due time
# [78] over due time
# [46] over due time
# [18] over due time
# [28] over due time
# [81] over due time
# [33] over due time
# [82] over due time
# [35] over due time
# [36] over due time
# [50] over due time
# [47] over due time
# [48] over due time
# [9] over due time
# [71] over due time
# [65] over due time
# [51] over due time
# [7] over due time
# [49] over due time
# [52] over due time
# [19] over due time
# [66] over due time
# [1, 70] over due time
# [20] over due time
# [11] over due time
# [88] over due time
# [64] over due time
# [62] over due time
# [30] over due time
# [69] over due time
# [70, 1] over due time
# [63] over due time
# [32] over due time
# [31] over due time
# [10] over due time
# [27] over due time
# [90] over due time
# ----結合1 [3, 68]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [4, 25]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [29] over due time
# [24] over due time
# [80] over waiting limit
# [34] over due time
# [78] over due time
# [79] over due time
# [77] over waiting limit
# [35] over due time
# [55] over due time
# [54] over due time
# [81] over due time
# [25, 4] over due time
# [65] over due time
# [33] over due time
# [9] over due time
# [71] over due time
# [67] over due time
# [76] over due time
# [12] over due time
# [51] over due time
# [39] over due time
# [4, 25] over due time
# [66] over due time
# [50] over due time
# [20] over due time
# [23] over due time
# [56] over due time
# [30] over due time
# [75] over due time
# [72] over due time
# [32] over due time
# [1, 70] over due time
# [26] over due time
# [74] over due time
# [21] over due time
# [70, 1] over due time
# [90] over due time
# [41] over due time
# [63] over due time
# [10] over due time
# [69] over due time
# [28] over due time
# [64] over due time
# [40] over due time
# [31] over due time
# [11] over due time
# [62] over due time
# [15] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [57] over due time
# [88] over due time
# [49] over due time
# [19] over due time
# [58, 91, 43, 22, 73, 2] over waiting limit
# [27] over due time
# [53] over due time
# [42] over due time
# [7] over due time
# [36] over due time
# [87] over due time
# [47] over due time
# [48] over due time
# [52] over due time
# [14] over due time
# [13] over due time
# [82] over due time
# [97] over due time
# [38] over due time
# [46] over due time
# [100] over due time
# [37] over due time
# [95] over due time
# [44] over due time
# [92] over due time
# [98] over due time
# [8] over due time
# [18] over due time
# [94] over due time
# [59] over due time
# [85] over due time
# [93] over due time
# [16] over due time
# [86] over due time
# [99] over due time
# [96] over due time
# [45] over due time
# [83] over due time
# [61] over due time
# [6] over due time
# [89] over due time
# [60] over due time
# [5] over due time
# [17] over due time
# [84] over due time
# ----結合1 [4, 25]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3, 68]
# 結合2 [5]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# 結合2 [92]
# 結合2 [93]
# 結合2 [94]
# 結合2 [95]
# 結合2 [96]
# 結合2 [97]
# 結合2 [98]
# 結合2 [99]
# 結合2 [100]
# [67] over due time
# [55] over due time
# [39] over due time
# [23] over due time
# [24] over due time
# [56] over due time
# [54] over due time
# [75] over due time
# [29] over due time
# [74] over due time
# [72] over due time
# [41] over due time
# [80] over due time
# [34] over due time
# [68, 3] over due time
# [78] over due time
# [21] over due time
# [79] over due time
# [35] over due time
# [3, 68] over due time
# [12] over due time
# [77] over due time
# [65] over due time
# [15] over due time
# [81] over due time
# [71] over due time
# [9] over due time
# [33] over due time
# [57] over due time
# [26] over due time
# [76] over due time
# [2, 73, 22, 43, 91, 58] over due time
# [51] over due time
# [40] over due time
# [66] over due time
# [50] over due time
# [42] over due time
# [20] over due time
# [87] over due time
# [14] over due time
# [38] over due time
# [58, 91, 43, 22, 73, 2] over due time
# [30] over due time
# [1, 70] over due time
# [44] over due time
# [97] over due time
# [100] over due time
# [28] over due time
# [32] over due time
# [37] over due time
# [13] over due time
# [70, 1] over due time
# [92] over due time
# [98] over due time
# [95] over due time
# [53] over due time
# [86] over due time
# [90] over due time
# [16] over due time
# [85] over due time
# [59] over due time
# [69] over due time
# [93] over due time
# [63] over due time
# [94] over due time
# [61] over due time
# [10] over due time
# [99] over due time
# [96] over due time
# [31] over due time
# [64] over due time
# [6] over due time
# [11] over due time
# [5] over due time
# [62] over due time
# [17] over due time
# [84] over due time
# [27] over due time
# [88] over due time
# [60] over due time
# [19] over due time
# [49] over due time
# [45] over due time
# [83] over due time
# [89] over due time
# [7] over due time
# [52] over due time
# [47] over due time
# [36] over due time
# [48] over due time
# [8] over due time
# [18] over due time
# [46] over due time
# [82] over due time
# ----結合1 [5]
# 結合2 [1, 70]
# 結合2 [2, 73, 22, 43, 91, 58]
# 結合2 [3, 68]
# 結合2 [4, 25]
# 結合2 [6]
# 結合2 [7]
# 結合2 [8]
# 結合2 [9]
# 結合2 [10]
# 結合2 [11]
# 結合2 [12]
# 結合2 [13]
# 結合2 [14]
# 結合2 [15]
# 結合2 [16]
# 結合2 [17]
# 結合2 [18]
# 結合2 [19]
# 結合2 [20]
# 結合2 [21]
# 結合2 [23]
# 結合2 [24]
# 結合2 [26]
# 結合2 [27]
# 結合2 [28]
# 結合2 [29]
# 結合2 [30]
# 結合2 [31]
# 結合2 [32]
# 結合2 [33]
# 結合2 [34]
# 結合2 [35]
# 結合2 [36]
# 結合2 [37]
# 結合2 [38]
# 結合2 [39]
# 結合2 [40]
# 結合2 [41]
# 結合2 [42]
# 結合2 [44]
# 結合2 [45]
# 結合2 [46]
# 結合2 [47]
# 結合2 [48]
# 結合2 [49]
# 結合2 [50]
# 結合2 [51]
# 結合2 [52]
# 結合2 [53]
# 結合2 [54]
# 結合2 [55]
# 結合2 [56]
# 結合2 [57]
# 結合2 [59]
# 結合2 [60]
# 結合2 [61]
# 結合2 [62]
# 結合2 [63]
# 結合2 [64]
# 結合2 [65]
# 結合2 [66]
# 結合2 [67]
# 結合2 [69]
# 結合2 [71]
# 結合2 [72]
# 結合2 [74]
# 結合2 [75]
# 結合2 [76]
# 結合2 [77]
# 結合2 [78]
# 結合2 [79]
# 結合2 [80]
# 結合2 [81]
# 結合2 [82]
# 結合2 [83]
# 結合2 [84]
# 結合2 [85]
# 結合2 [86]
# 結合2 [87]
# 結合2 [88]
# 結合2 [89]
# 結合2 [90]
# ...
# [81] over due time
# [33, 29, 79, 32] over due time
# [45, 82, 53] over due time
# [50, 40, 21] over due time
# [52, 7, 46, 77] over due time
# [83, 16, 84] over due time
# [17, 49, 19, 47] over due time
# [77, 46, 7, 52] over waiting limit
# [84, 16, 83] over due time
# [76, 72] over due time
# [68, 3, 88, 31] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [24, 57, 75] over due time
# [80, 66, 9, 30, 27] over waiting limit
# [27, 30, 9, 66, 80] over due time
# [89] over waiting limit
# [93, 60, 37, 8, 62, 63] over waiting limit
# [99, 94] over due time
# [38, 95, 59] over due time
# [54] over due time
# [96, 64, 36] over due time
# [55, 41, 23, 39] over due time
# [28, 12, 78, 34, 35] over due time
# [6, 4, 25] over due time
# [59, 95, 38] over due time
# [25, 4, 6] over due time
# [100, 13, 97, 86, 44, 5] over due time
# [14, 15, 87, 56, 74] over due time
# [92, 2, 73, 22, 43, 91, 58] over due time
# [94, 99] over due time
# [26, 85, 61, 98, 42] over due time
# [67, 48] over due time
# [39, 23, 41, 55] over due time
# [42, 98, 61, 85, 26] over due time
# [21, 40, 50] over due time
# [72, 76] over due time
# [75, 57, 24] over due time
# [74, 56, 87, 15, 14] over due time
# [53, 82, 45] over due time
# [58, 91, 43, 22, 73, 2, 92] over waiting limit
# ----結合1 [72, 76]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [75, 57, 24]
# 結合2 [81]
# 結合2 [83, 16, 84]
# 結合2 [89]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [99, 94]
# [77, 46, 7, 52] over waiting limit
# [81] over due time
# [35, 34, 78, 12, 28] over waiting limit
# [33, 29, 79, 32] over due time
# [68, 3, 88, 31] over waiting limit
# [65, 71] over due time
# [24, 57, 75] over waiting limit
# [80, 66, 9, 30, 27] over waiting limit
# [71, 65] over due time
# [50, 40, 21] over waiting limit
# [51] over due time
# [54] over waiting limit
# [55, 41, 23, 39] over waiting limit
# [25, 4, 6] over waiting limit
# [32, 79, 29, 33] over waiting limit
# [67, 48] over due time
# [70, 1, 20, 90, 11] over waiting limit
# [39, 23, 41, 55] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [10, 18, 69] over waiting limit
# [69, 18, 10] over due time
# [26, 85, 61, 98, 42] over waiting limit
# [28, 12, 78, 34, 35] over due time
# [31, 88, 3, 68] over due time
# [75, 57, 24] over due time
# [11, 90, 20, 1, 70] over due time
# [21, 40, 50] over due time
# [74, 56, 87, 15, 14] over waiting limit
# [36, 64, 96] over due time
# [47, 19, 49, 17] over due time
# [27, 30, 9, 66, 80] over due time
# [48, 67] over waiting limit
# [52, 7, 46, 77] over due time
# [58, 91, 43, 22, 73, 2, 92] over waiting limit
# [53, 82, 45] over due time
# [42, 98, 61, 85, 26] over due time
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [14, 15, 87, 56, 74] over due time
# [89] over waiting limit
# [38, 95, 59] over due time
# [100, 13, 97, 86, 44, 5] over waiting limit
# [17, 49, 19, 47] over waiting limit
# [92, 2, 73, 22, 43, 91, 58] over due time
# [84, 16, 83] over due time
# [94, 99] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [59, 95, 38] over due time
# [93, 60, 37, 8, 62, 63] over waiting limit
# [96, 64, 36] over waiting limit
# [99, 94] over due time
# [6, 4, 25] over due time
# ----結合1 [75, 57, 24]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [81]
# 結合2 [83, 16, 84]
# 結合2 [89]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [99, 94]
# [25, 4, 6] over due time
# [55, 41, 23, 39] over due time
# [67, 48] over due time
# [54] over due time
# [80, 66, 9, 30, 27] over due time
# [68, 3, 88, 31] over due time
# [35, 34, 78, 12, 28] over due time
# [39, 23, 41, 55] over due time
# [65, 71] over due time
# [81] over due time
# [71, 65] over due time
# [77, 46, 7, 52] over due time
# [33, 29, 79, 32] over due time
# [51] over due time
# [76, 72] over due time
# [72, 76] over due time
# [74, 56, 87, 15, 14] over due time
# [50, 40, 21] over due time
# [21, 40, 50] over due time
# [26, 85, 61, 98, 42] over due time
# [32, 79, 29, 33] over due time
# [70, 1, 20, 90, 11] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [10, 18, 69] over due time
# [28, 12, 78, 34, 35] over due time
# [69, 18, 10] over due time
# [11, 90, 20, 1, 70] over due time
# [31, 88, 3, 68] over due time
# [58, 91, 43, 22, 73, 2, 92] over due time
# [42, 98, 61, 85, 26] over due time
# [53, 82, 45] over due time
# [14, 15, 87, 56, 74] over due time
# [38, 95, 59] over due time
# [27, 30, 9, 66, 80] over due time
# [100, 13, 97, 86, 44, 5] over due time
# [36, 64, 96] over due time
# [92, 2, 73, 22, 43, 91, 58] over due time
# [47, 19, 49, 17] over due time
# [48, 67] over due time
# [52, 7, 46, 77] over due time
# [59, 95, 38] over due time
# [94, 99] over due time
# [93, 60, 37, 8, 62, 63] over due time
# [99, 94] over due time
# [96, 64, 36] over due time
# [6, 4, 25] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [17, 49, 19, 47] over due time
# [84, 16, 83] over due time
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [89] over due time
# ----結合1 [81]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [75, 57, 24]
# 結合2 [83, 16, 84]
# 結合2 [89]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [99, 94]
# [35, 34, 78, 12, 28] over waiting limit
# [65, 71] over due time
# [71, 65] over due time
# [33, 29, 79, 32] over due time
# [51] over due time
# [32, 79, 29, 33] over waiting limit
# [24, 57, 75] over waiting limit
# [77, 46, 7, 52] over waiting limit
# [68, 3, 88, 31] over waiting limit
# [50, 40, 21] over due time
# [80, 66, 9, 30, 27] over waiting limit
# [63, 62, 8, 37, 60, 93] over due time
# [70, 1, 20, 90, 11] over waiting limit
# [76, 72] over due time
# [10, 18, 69] over due time
# [55, 41, 23, 39] over due time
# [25, 4, 6] over waiting limit
# [54] over waiting limit
# [11, 90, 20, 1, 70] over due time
# [67, 48] over due time
# [31, 88, 3, 68] over due time
# [69, 18, 10] over due time
# [39, 23, 41, 55] over due time
# [36, 64, 96] over due time
# [47, 19, 49, 17] over due time
# [48, 67] over waiting limit
# [26, 85, 61, 98, 42] over due time
# [75, 57, 24] over due time
# [28, 12, 78, 34, 35] over due time
# [72, 76] over due time
# [74, 56, 87, 15, 14] over due time
# [21, 40, 50] over due time
# [52, 7, 46, 77] over due time
# [27, 30, 9, 66, 80] over due time
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [53, 82, 45] over due time
# [58, 91, 43, 22, 73, 2, 92] over waiting limit
# [17, 49, 19, 47] over due time
# [84, 16, 83] over due time
# [89] over waiting limit
# [5, 44, 86, 97, 13, 100] over due time
# [42, 98, 61, 85, 26] over due time
# [6, 4, 25] over due time
# [99, 94] over due time
# [96, 64, 36] over due time
# [93, 60, 37, 8, 62, 63] over waiting limit
# [14, 15, 87, 56, 74] over due time
# [59, 95, 38] over due time
# [38, 95, 59] over due time
# [94, 99] over due time
# [100, 13, 97, 86, 44, 5] over waiting limit
# [92, 2, 73, 22, 43, 91, 58] over due time
# ----結合1 [83, 16, 84]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [75, 57, 24]
# 結合2 [81]
# 結合2 [89]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [99, 94]
# [17, 49, 19, 47] over waiting limit
# [45, 82, 53] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [38, 95, 59] over due time
# [36, 64, 96] over due time
# [14, 15, 87, 56, 74] over due time
# [93, 60, 37, 8, 62, 63] over waiting limit
# [100, 13, 97, 86, 44, 5] over waiting limit
# [47, 19, 49, 17] over due time
# [99, 94] over due time
# [48, 67] over waiting limit
# [59, 95, 38] over due time
# [92, 2, 73, 22, 43, 91, 58] over due time
# [96, 64, 36] over waiting limit
# [42, 98, 61, 85, 26] over due time
# [11, 90, 20, 1, 70] over due time
# [6, 4, 25] over due time
# [94, 99] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [89] over waiting limit
# [52, 7, 46, 77] over due time
# [10, 18, 69] over due time
# [32, 79, 29, 33] over due time
# [31, 88, 3, 68] over due time
# [74, 56, 87, 15, 14] over due time
# [70, 1, 20, 90, 11] over waiting limit
# [75, 57, 24] over due time
# [58, 91, 43, 22, 73, 2, 92] over waiting limit
# [72, 76] over due time
# [21, 40, 50] over due time
# [67, 48] over due time
# [69, 18, 10] over due time
# [39, 23, 41, 55] over due time
# [65, 71] over due time
# [71, 65] over due time
# [51] over due time
# [27, 30, 9, 66, 80] over due time
# [35, 34, 78, 12, 28] over due time
# [53, 82, 45] over due time
# [25, 4, 6] over due time
# [81] over due time
# [55, 41, 23, 39] over due time
# [33, 29, 79, 32] over due time
# [50, 40, 21] over due time
# [26, 85, 61, 98, 42] over due time
# [54] over due time
# [76, 72] over due time
# [77, 46, 7, 52] over waiting limit
# [24, 57, 75] over due time
# [28, 12, 78, 34, 35] over due time
# [80, 66, 9, 30, 27] over waiting limit
# [68, 3, 88, 31] over due time
# ----結合1 [89]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [75, 57, 24]
# 結合2 [81]
# 結合2 [83, 16, 84]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [99, 94]
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [17, 49, 19, 47] over due time
# [84, 16, 83] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [36, 64, 96] over due time
# [99, 94] over due time
# [93, 60, 37, 8, 62, 63] over due time
# [47, 19, 49, 17] over due time
# [48, 67] over due time
# [96, 64, 36] over due time
# [6, 4, 25] over due time
# [38, 95, 59] over due time
# [59, 95, 38] over due time
# [100, 13, 97, 86, 44, 5] over due time
# [92, 2, 73, 22, 43, 91, 58] over due time
# [14, 15, 87, 56, 74] over due time
# [94, 99] over due time
# [52, 7, 46, 77] over due time
# [11, 90, 20, 1, 70] over due time
# [42, 98, 61, 85, 26] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [10, 18, 69] over due time
# [31, 88, 3, 68] over due time
# [32, 79, 29, 33] over due time
# [70, 1, 20, 90, 11] over due time
# [69, 18, 10] over due time
# [58, 91, 43, 22, 73, 2, 92] over due time
# [74, 56, 87, 15, 14] over due time
# [27, 30, 9, 66, 80] over due time
# [65, 71] over due time
# [75, 57, 24] over due time
# [51] over due time
# [71, 65] over due time
# [72, 76] over due time
# [21, 40, 50] over due time
# [35, 34, 78, 12, 28] over due time
# [67, 48] over due time
# [39, 23, 41, 55] over due time
# [81] over due time
# [33, 29, 79, 32] over due time
# [50, 40, 21] over due time
# [53, 82, 45] over due time
# [25, 4, 6] over due time
# [76, 72] over due time
# [55, 41, 23, 39] over due time
# [77, 46, 7, 52] over due time
# [26, 85, 61, 98, 42] over due time
# [54] over due time
# [28, 12, 78, 34, 35] over due time
# [68, 3, 88, 31] over due time
# [80, 66, 9, 30, 27] over due time
# [24, 57, 75] over due time
# ----結合1 [92, 2, 73, 22, 43, 91, 58]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [75, 57, 24]
# 結合2 [81]
# 結合2 [83, 16, 84]
# 結合2 [89]
# 結合2 [99, 94]
# [74, 56, 87, 15, 14] over due time
# [75, 57, 24] over due time
# [72, 76] over due time
# [21, 40, 50] over due time
# [42, 98, 61, 85, 26] over due time
# [67, 48] over due time
# [39, 23, 41, 55] over due time
# [14, 15, 87, 56, 74] over due time
# [38, 95, 59] over due time
# [100, 13, 97, 86, 44, 5] over due time
# [25, 4, 6] over due time
# [55, 41, 23, 39] over due time
# [59, 95, 38] over due time
# [93, 60, 37, 8, 62, 63] over due time
# [94, 99] over due time
# [54] over due time
# [99, 94] over due time
# [26, 85, 61, 98, 42] over due time
# [96, 64, 36] over due time
# [24, 57, 75] over due time
# [6, 4, 25] over due time
# [53, 82, 45] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [17, 49, 19, 47] over due time
# [84, 16, 83] over due time
# [80, 66, 9, 30, 27] over due time
# [68, 3, 88, 31] over due time
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [77, 46, 7, 52] over due time
# [89] over due time
# [76, 72] over due time
# [28, 12, 78, 34, 35] over due time
# [81] over due time
# [33, 29, 79, 32] over due time
# [35, 34, 78, 12, 28] over due time
# [36, 64, 96] over due time
# [50, 40, 21] over due time
# [47, 19, 49, 17] over due time
# [48, 67] over due time
# [71, 65] over due time
# [65, 71] over due time
# [51] over due time
# [52, 7, 46, 77] over due time
# [11, 90, 20, 1, 70] over due time
# [69, 18, 10] over due time
# [70, 1, 20, 90, 11] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [32, 79, 29, 33] over due time
# [31, 88, 3, 68] over due time
# [10, 18, 69] over due time
# [27, 30, 9, 66, 80] over due time
# ----結合1 [99, 94]
# 結合2 [5, 44, 86, 97, 13, 100]
# 結合2 [6, 4, 25]
# 結合2 [11, 90, 20, 1, 70]
# 結合2 [14, 15, 87, 56, 74]
# 結合2 [21, 40, 50]
# 結合2 [27, 30, 9, 66, 80]
# 結合2 [28, 12, 78, 34, 35]
# 結合2 [31, 88, 3, 68]
# 結合2 [33, 29, 79, 32]
# 結合2 [36, 64, 96]
# 結合2 [39, 23, 41, 55]
# 結合2 [42, 98, 61, 85, 26]
# 結合2 [45, 82, 53]
# 結合2 [47, 19, 49, 17]
# 結合2 [51]
# 結合2 [52, 7, 46, 77]
# 結合2 [54]
# 結合2 [59, 95, 38]
# 結合2 [63, 62, 8, 37, 60, 93]
# 結合2 [65, 71]
# 結合2 [67, 48]
# 結合2 [69, 18, 10]
# 結合2 [72, 76]
# 結合2 [75, 57, 24]
# 結合2 [81]
# 結合2 [83, 16, 84]
# 結合2 [89]
# 結合2 [92, 2, 73, 22, 43, 91, 58]
# [38, 95, 59] over due time
# [100, 13, 97, 86, 44, 5] over waiting limit
# [92, 2, 73, 22, 43, 91, 58] over due time
# [59, 95, 38] over due time
# [14, 15, 87, 56, 74] over due time
# [93, 60, 37, 8, 62, 63] over waiting limit
# [96, 64, 36] over waiting limit
# [42, 98, 61, 85, 26] over due time
# [5, 44, 86, 97, 13, 100] over due time
# [17, 49, 19, 47] over waiting limit
# [84, 16, 83] over due time
# [6, 4, 25] over due time
# [45, 82, 53] over due time
# [83, 16, 84] over due time
# [89] over waiting limit
# [36, 64, 96] over due time
# [74, 56, 87, 15, 14] over waiting limit
# [47, 19, 49, 17] over due time
# [75, 57, 24] over due time
# [48, 67] over waiting limit
# [58, 91, 43, 22, 73, 2, 92] over waiting limit
# [72, 76] over due time
# [21, 40, 50] over due time
# [67, 48] over due time
# [39, 23, 41, 55] over due time
# [52, 7, 46, 77] over due time
# [11, 90, 20, 1, 70] over due time
# [25, 4, 6] over waiting limit
# [55, 41, 23, 39] over due time
# [63, 62, 8, 37, 60, 93] over due time
# [53, 82, 45] over due time
# [10, 18, 69] over due time
# [31, 88, 3, 68] over due time
# [26, 85, 61, 98, 42] over due time
# [54] over due time
# [32, 79, 29, 33] over due time
# [24, 57, 75] over due time
# [70, 1, 20, 90, 11] over waiting limit
# [80, 66, 9, 30, 27] over waiting limit
# [69, 18, 10] over due time
# [27, 30, 9, 66, 80] over due time
# [68, 3, 88, 31] over due time
# [51] over due time
# [65, 71] over due time
# [77, 46, 7, 52] over waiting limit
# [28, 12, 78, 34, 35] over due time
# [71, 65] over due time
# [76, 72] over due time
# [35, 34, 78, 12, 28] over due time
# [50, 40, 21] over due time
# [81] over due time
# [33, 29, 79, 32] over due time

# %%
print count
# Out:
# 72

# %%
print 'Number of cars is',len(route)
# Out:
# Number of cars is 29

# %%
totaltraveltime = []
for indexi, i in enumerate(leavetime):
    totaltraveltime.append(i[-1]+distance_matrix[route[indexi][-1]][0])
print 'Travel time for each route:'
for indexi,i in enumerate(totaltraveltime):
    print indexi,i
print 'Total travel time is',sum(totaltraveltime)
# Out:
# Travel time for each route:
# 0 219.04163056
# 1 215.541019662
# 2 213.09502311
# 3 183.596747752
# 4 150.970562748
# 5 213.09502311
# 6 194.036569057
# 7 173.377558326
# 8 185.0
# 9 160.264337522
# 10 176.463092423
# 11 153.180339887
# 12 109.472135955
# 13 197.413812651
# 14 124.925824036
# 15 208.697715604
# 16 172.803508502
# 17 135.426406871
# 18 218.248456731
# 19 126.66106403
# 20 202.802877549
# 21 159.495097568
# 22 98.6524758425
# 23 193.0
# 24 131.586228448
# 25 135.331050121
# 26 195.0
# 27 219.055385138
# 28 122.041594579
# Total travel time is 4988.27553779

# %%
eachdemand = []
for i in route:
    c = 0
    for j in i:
        c += demand[j]
    eachdemand.append(c)

print 'Demand for each route:'
for indexi,i in enumerate(eachdemand):
    print indexi,i
# Out:
# Demand for each route:
# 0 131.0
# 1 28.0
# 2 39.0
# 3 68.0
# 4 33.0
# 5 84.0
# 6 60.0
# 7 85.0
# 8 66.0
# 9 25.0
# 10 67.0
# 11 86.0
# 12 46.0
# 13 76.0
# 14 10.0
# 15 29.0
# 16 18.0
# 17 64.0
# 18 71.0
# 19 35.0
# 20 61.0
# 21 34.0
# 22 38.0
# 23 28.0
# 24 26.0
# 25 37.0
# 26 15.0
# 27 62.0
# 28 36.0

# %%
print route
# Out:
# [[5, 44, 86, 97, 13, 100], [6, 4, 25], [11, 90, 20, 1, 70], [14, 15, 87, 56, 74], [21, 40, 50], [27, 30, 9, 66, 80], [28, 12, 78, 34, 35], [31, 88, 3, 68], [33, 29, 79, 32], [36, 64, 96], [39, 23, 41, 55], [42, 98, 61, 85, 26], [45, 82, 53], [47, 19, 49, 17], [51], [52, 7, 46, 77], [54], [59, 95, 38], [63, 62, 8, 37, 60, 93], [65, 71], [67, 48], [69, 18, 10], [72, 76], [75, 57, 24], [81], [83, 16, 84], [89], [92, 2, 73, 22, 43, 91, 58], [99, 94]]

# %%
print leavetime
# Out:
# [[44.0, 79.0, 104.0, 143.0, 169.0, 195.0], [109.0, 159.0, 182.0], [77.0, 105.0, 136.0, 171.0, 192.0], [42.01562118716424, 71.0, 103.0, 140.0, 159.0], [72.0, 95.0, 134.0], [47.0, 81.0, 107.0, 137.0, 192.0], [49.0, 73.0, 106.0, 127.0, 153.0], [60.0, 84.0, 126.0, 152.0], [47.0, 73.0, 102.0, 151.0], [51.400483088968905, 83.0, 145.0], [54.0, 78.0, 107.0, 146.0], [41.0, 68.0, 86.0, 101.0, 142.0], [42.0, 65.0, 105.0], [61.0, 86.0, 118.0, 167.0], [98.0], [62.0, 91.0, 127.0, 189.0], [150.0], [28.0, 49.0, 93.0], [44.92849839314596, 68.0, 105.0, 144.0, 172.0, 198.0], [61.0, 87.0], [93.0, 175.0], [60.0, 97.0, 134.0], [45.0, 83.0], [79.0, 111.0, 163.0], [104.0], [54.0, 85.0, 111.0], [186.0], [28.384776310850235, 60.0, 88.0, 107.0, 142.0, 170.0, 210.0], [93.0, 110.0]]
